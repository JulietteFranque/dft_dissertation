# %%
import os
os.chdir('../')
from forced_convection_dft.forward_models import ForwardModelDft, ForwardModelThermocouple
from forced_convection_dft.correlations import PlateCorrelations, SphereCorrelations
from dft import dft_models, heat_transfer_coefficients
os.chdir('jupyter_notebooks')
import numpy as np
import matplotlib.pyplot as plt

# %%
n_points = 500
time_vector = np.linspace(0, 500, n_points)
velocity =  np.ones(n_points) * 5


diameter_tc = 1.4e-3
density_tc = 8665
heat_capacity_tc = 485.6 
emissivity_tc=0.8
alpha_tc=0.8

dft_thickness =  0.0016
length_insulation = .019
plate_side_length = .0762

temperature_initial = 21 + 273

# %%
#fluxes = np.linspace(.0001, .0005, 5)
fluxes = np.linspace(5, 150, 5)
mean_percentage_errors = []
for flux in fluxes:
    #incident_heat_flux = time_vector**2 * flux * 1e3 #W/m2
    incident_heat_flux = np.ones(n_points) * flux * 1e3
    incident_heat_flux[time_vector < 100] = 0
    incident_heat_flux[time_vector > 400] = 0
    forward_dft = ForwardModelDft(number_of_nodes=10, time_vector=time_vector, insulation_thickness=length_insulation, plate_thickness=dft_thickness, incident_heat_flux=incident_heat_flux,
                 characteristic_velocity=velocity, initial_temperature=temperature_initial, temperature_ambient=temperature_initial, temperature_surroundings=temperature_initial, plate_side_length=plate_side_length)
    temperature_front, temperature_back, temperature_insulation, coefficient_front, coefficient_back = forward_dft.run()
    coefficient_front_nat = heat_transfer_coefficients.natural_convection(
            (temperature_front + temperature_initial).reshape(-1, 1) / 2, Kelvin=True,
           T_infty=temperature_initial).custom(0.65, 0.25).flatten()
    #print(coefficient_front)
    inverse_model_nat_conv = dft_models.one_dim_conduction(T_f=temperature_front, T_b=temperature_back, time=time_vector, h_f=coefficient_front_nat, h_b=coefficient_back, model='one_d_conduction', Kelvin=True, T_inf=temperature_initial, T_sur=temperature_initial)
    inverse_model_nat_forced = dft_models.one_dim_conduction(T_f=temperature_front, T_b=temperature_back, time=time_vector, h_f=coefficient_front, h_b=coefficient_back, model='one_d_conduction', Kelvin=True, T_inf=temperature_initial, T_sur=temperature_initial)
    errors = np.abs((incident_heat_flux/1e3 - inverse_model_nat_conv.q_inc) / (incident_heat_flux/1e3) * 100)
    mean_error = np.mean(errors[np.isfinite(errors)])
    mean_percentage_errors.append(mean_error)
    plt.plot(time_vector, incident_heat_flux/1e3, label='true', color='orange')
    plt.plot(time_vector, inverse_model_nat_conv.q_inc, label='assuming nat', color='red')
    plt.plot(time_vector, inverse_model_nat_forced.q_inc, label='using forced h', color='dodgerblue')
    plt.ylabel('heat flux (kW/m2)')
    plt.legend()
    plt.figure()
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 499/499 [00:00<00:00, 7798.60it/s]
# /var/folders/5t/ltqvfkd124z1n5v3ntgw77d40000gn/T/ipykernel_7769/3796280664.py:18: RuntimeWarning: divide by zero encountered in true_divide
#   errors = np.abs((incident_heat_flux/1e3 - inverse_model_nat_conv.q_inc) / (incident_heat_flux/1e3) * 100)
# /var/folders/5t/ltqvfkd124z1n5v3ntgw77d40000gn/T/ipykernel_7769/3796280664.py:18: RuntimeWarning: invalid value encountered in true_divide
#   errors = np.abs((incident_heat_flux/1e3 - inverse_model_nat_conv.q_inc) / (incident_heat_flux/1e3) * 100)
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 499/499 [00:00<00:00, 8073.41it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 499/499 [00:00<00:00, 8011.05it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 499/499 [00:00<00:00, 8192.93it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 499/499 [00:00<00:00, 7944.84it/s]

# %%
#incident_heat_flux = time_vector ** 2 * .001 * 1e3
incident_heat_flux = np.ones(n_points) * 10 * 1e3
#incident_heat_flux[time_vector < 100] = 0
#incident_heat_flux[time_vector > 400] = 0

plt.plot(time_vector, incident_heat_flux / 1e3)
forward_dft = ForwardModelDft(number_of_nodes=10, time_vector=time_vector, insulation_thickness=length_insulation, plate_thickness=length_dft_side, incident_heat_flux=incident_heat_flux,
                 characteristic_velocity=velocity, initial_temperature=temperature_initial, temperature_ambient=temperature_initial, temperature_surroundings=temperature_initial)
temperature_front, temperature_back, temperature_insulation, coefficient_front, coefficient_back = forward_dft.run()


forward_tc = ForwardModelThermocouple(time_vector, incident_heat_flux, velocity, temperature_initial,
                 temperature_initial, temperature_initial, emissivity_tc, alpha_tc, diameter_tc, heat_capacity_tc,
                 density_tc)
temperature_tc = forward_tc.run()
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 499/499 [00:00<00:00, 7110.39it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 499/499 [00:00<00:00, 5754.22it/s]

# %%
plt.plot(temperature_tc-273, label='tc')
plt.plot(temperature_front-273, label='front')
plt.plot(temperature_back-273, label='back')
plt.legend()

# %%
def find_thermocouple_q_inc(h_tc, thermocouple_temperature, ambient_temperature, temperature_surroundings, diameter, emissivity, absorptivity, heat_capacity, density):
    convective_heat_flux = h_tc * (thermocouple_temperature - ambient_temperature)
    area = 4 * np.pi * (diameter / 2) ** 2
    volume = 4 / 3 * np.pi * (diameter / 2) ** 3
    emitted_heat_flux = emissivity * 5.67e-8 * (
            thermocouple_temperature ** 4 - temperature_surroundings ** 4)
    energy_stored = (density * heat_capacity * volume) * np.gradient(thermocouple_temperature, time_vector)
    incident_heat_flux = (energy_stored/area + convective_heat_flux + emitted_heat_flux) / absorptivity
    return incident_heat_flux / 1e3

# %%
def minimize_error(velocity, ambient_temperature, temperature_tc, temperature_front_dft, temperature_back_dft, plate_thickness, diameter, emissivity, absorptivity, heat_capacity, density):
    h_front_dft = PlateCorrelations(surface_temperature=temperature_front_dft, ambient_temperature=ambient_temperature,characteristic_length=plate_thickness).find_forced_convection_heat_transfer_coefficient(velocity)
    h_back_dft = heat_transfer_coefficients.natural_convection(
            (temperature_back + temperature_initial).reshape(-1, 1) / 2, Kelvin=True,
           T_infty=temperature_initial).custom(0.65, 0.25).flatten()
    h_tc = SphereCorrelations(
                surface_temperature=temperature_tc,
                ambient_temperature=ambient_temperature,
                characteristic_length=diameter).find_forced_convection_heat_transfer_coefficient(velocity)
    q_inc_plate = dft_models.one_dim_conduction(T_f=temperature_front, T_b=temperature_back, time=time_vector, h_f=coefficient_front, h_b=coefficient_back, model='one_d_conduction', Kelvin=True, T_inf=temperature_initial, T_sur=temperature_initial).q_inc
    q_inc_tc = find_thermocouple_q_inc(h_tc, temperature_tc, ambient_temperature, ambient_temperature, diameter, emissivity, absorptivity, heat_capacity, density)
    #plt.plot(q_inc_plate, label='plate')
    #plt.plot(q_inc_tc, label='tc')
    #plt.legend()
    return np.abs(q_inc_plate - q_inc_tc).sum()

# %%
minimize_error(velocity, temperature_initial, temperature_tc, temperature_front, temperature_back, length_dft_side, diameter_tc, emissivity_tc, alpha_tc, heat_capacity_tc, density_tc)
# Out:
# 171.1697517706196

# %%
from scipy.optimize import minimize

# %%
x0 = np.ones(time_vector.shape[0])
res = minimize(lambda x: minimize_error(x, temperature_initial, temperature_tc, temperature_front, temperature_back, length_dft_side, diameter_tc, emissivity_tc, alpha_tc, heat_capacity_tc, density_tc ), x0, method='powell',
               options={'ftol': 1, 'disp': True}, bounds=list((((0, np.inf), ) * time_vector.shape[0])))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.001663
#          Iterations: 3
#          Function evaluations: 23907

# %%
plt.plot(res.x)
plt.ylim(0, 10)
# Out:
# (0.0, 10.0)

# %%
res.x
# Out:
# array([6.03162104e+04, 6.03162104e+04, 8.67986163e-01, 1.48880945e+00,
#        2.10349760e+00, 2.58914801e+00, 2.96402315e+00, 3.25618180e+00,
#        3.48761467e+00, 3.67399873e+00, 3.82643061e+00, 3.95276324e+00,
#        4.05884266e+00, 4.14878949e+00, 4.22581952e+00, 4.29240797e+00,
#        4.35036328e+00, 4.40119105e+00, 4.44604601e+00, 4.48584912e+00,
#        4.52134223e+00, 4.55316682e+00, 4.58183428e+00, 4.60773821e+00,
#        4.63127873e+00, 4.65266568e+00, 4.67223011e+00, 4.69018480e+00,
#        4.70664367e+00, 4.72183944e+00, 4.73587993e+00, 4.74888220e+00,
#        4.76093827e+00, 4.77216520e+00, 4.78264273e+00, 4.79240804e+00,
#        4.80156404e+00, 4.81012933e+00, 4.81817245e+00, 4.82573730e+00,
#        4.83289991e+00, 4.83963148e+00, 4.84599279e+00, 4.85198919e+00,
#        4.85768974e+00, 4.86309907e+00, 4.86824526e+00, 4.87314299e+00,
#        4.87781941e+00, 4.88224538e+00, 4.88649260e+00, 4.89058397e+00,
#        4.89447984e+00, 4.89820977e+00, 4.90179190e+00, 4.90523585e+00,
#        4.90855080e+00, 4.91174378e+00, 4.91482327e+00, 4.91779681e+00,
#        4.92067029e+00, 4.92345082e+00, 4.92614362e+00, 4.92875460e+00,
#        4.93128845e+00, 4.93375004e+00, 4.93614424e+00, 4.93848132e+00,
#        4.94075162e+00, 4.94296495e+00, 4.94512569e+00, 4.94723645e+00,
#        4.94930046e+00, 4.95131945e+00, 4.95329704e+00, 4.95523487e+00,
#        4.95713592e+00, 4.95900129e+00, 4.96083400e+00, 4.96263513e+00,
#        4.96440647e+00, 4.96615104e+00, 4.96786820e+00, 4.96955931e+00,
#        4.97122787e+00, 4.97287401e+00, 4.97449934e+00, 4.97610275e+00,
#        4.97768918e+00, 4.97925637e+00, 4.98080617e+00, 4.98233982e+00,
#        4.98385790e+00, 4.98536118e+00, 4.98688317e+00, 4.98835896e+00,
#        4.98982294e+00, 4.99127414e+00, 4.99271362e+00, 4.99414204e+00,
#        4.99555994e+00, 4.99696781e+00, 4.99836612e+00, 4.99975492e+00,
#        5.00113519e+00, 5.00250738e+00, 5.00387121e+00, 5.00522689e+00,
#        5.00657560e+00, 5.00791748e+00, 5.00924277e+00, 5.01057133e+00,
#        5.26971277e+00, 5.27023115e+00, 5.27069114e+00, 5.27123460e+00,
#        5.27177572e+00, 5.27231465e+00, 5.27287508e+00, 5.27340862e+00,
#        5.27394009e+00, 5.27446960e+00, 5.27499712e+00, 5.27552226e+00,
#        5.27604581e+00, 5.27656739e+00, 5.27708733e+00, 5.27760461e+00,
#        5.27812045e+00, 5.27863458e+00, 5.27914549e+00, 5.27965646e+00,
#        5.28016478e+00, 5.28067164e+00, 5.28117629e+00, 5.28167877e+00,
#        5.28217966e+00, 5.28267884e+00, 5.28317623e+00, 5.28367183e+00,
#        5.28416565e+00, 5.28465780e+00, 5.28514899e+00, 5.28563825e+00,
#        5.28612575e+00, 5.28661147e+00, 5.28709544e+00, 5.28757939e+00,
#        5.28806002e+00, 5.28853878e+00, 5.28901576e+00, 5.28949287e+00,
#        5.28996669e+00, 5.29043706e+00, 5.29090771e+00, 5.29137669e+00,
#        5.29184382e+00, 5.29230897e+00, 5.29277439e+00, 5.29323633e+00,
#        5.29369644e+00, 5.29415531e+00, 5.29461234e+00, 5.29506777e+00,
#        5.29552175e+00, 5.29597169e+00, 5.29642244e+00, 5.29687116e+00,
#        5.29728582e+00, 5.29773162e+00, 5.29817726e+00, 5.29861849e+00,
#        5.29905976e+00, 5.29949790e+00, 5.29993577e+00, 5.30037119e+00,
#        5.30080476e+00, 5.30123704e+00, 5.30166651e+00, 5.30209607e+00,
#        5.30252349e+00, 5.30287052e+00, 5.30329781e+00, 5.30372527e+00,
#        5.30415190e+00, 5.30457619e+00, 5.30499986e+00, 5.30542045e+00,
#        5.30583932e+00, 5.30625558e+00, 5.30667103e+00, 5.30708454e+00,
#        5.30749637e+00, 5.30790649e+00, 5.30831493e+00, 5.30872269e+00,
#        5.30912781e+00, 5.30953130e+00, 5.30993323e+00, 5.31033360e+00,
#        5.31073238e+00, 5.31112867e+00, 5.31152539e+00, 5.31191833e+00,
#        5.31231088e+00, 5.31270189e+00, 5.31309137e+00, 5.31359756e+00])

# %%
sensor_1 = dft_models.one_dim_conduction(temperature_front[:-1], temperature_back, time_vector, hf + [167], hb + [0.26], model='one_d_conduction', Kelvin=True, T_inf=20+273, T_sur=20+273)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/5t/ltqvfkd124z1n5v3ntgw77d40000gn/T/ipykernel_54439/3890318156.py in <module>
# ----> 1 sensor_1 = dft_models.one_dim_conduction(temperature_front[:-1], temperature_back, time_vector, hf + [167], hb + [0.26], model='one_d_conduction', Kelvin=True, T_inf=20+273, T_sur=20+273)
#       2
#       3
#
# NameError: name 'hf' is not defined

# %%
plt.plot(time_vector, errors)
plt.xlim(0, 500)

# %%
np.mean(errors[np.isfinite(errors)])

# %%
plt.hist(errors[np.isfinite(errors)])

# %%
plt.plot(sensor_1.q_net)

# %%
sensor_1.q_net

# %%
sensor_1.T_nodes_i.shape

# %%
plt.plot(sensor_1.T_nodes_i, color='red')
plt.plot(temperature_insulation, color='blue')

# %%
plt.scatter(sensor_1.T_nodes_i.flatten(), temperature_insulation.flatten())

# %%
1 / 20
